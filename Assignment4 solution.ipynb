# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
waste=pd.read_csv('UNdata_Export_20200605_125934676.csv')

# %%
wastere=pd.read_csv('UNdata_Export_20200605_134640264.csv')

# %%
waste.head()
# Out:
#   Country or Area  Year    Value  Value Footnotes    Unit
# 0           India  2015  7803517              NaN  tonnes
# 1           India  2014  7423002              NaN  tonnes
# 2           India  2012  7900000              NaN  tonnes
# 3           India  2011  7903628              NaN  tonnes
# 4           India  2008  6232507              NaN  tonnes

# %%
wastere.head()
# Out:
#   Country or Area  Year    Value  Value Footnotes    Unit
# 0           India  2015  3152023              NaN  tonnes
# 1           India  2014  3254904              NaN  tonnes
# 2           India  2011  3980639              NaN  tonnes
# 3           India  2008  3088387              NaN  tonnes
# 4           India  2000  1429281              NaN  tonnes

# %%
plt.figure()
y=waste['Value']
x=waste['Year']
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1=wastere['Year']
y1=wastere['Value']
plt.plot(x1,y1)
plt.title('waste generated and recycled(tonnes)')
# Out:
# Text(0.5, 1, 'waste generated and recycled(tonnes)')

# %%
plt.legend(['waste generated', 'waste recycled'])

# %%
y
